# %%
# %cd kaggle/working
# Out:
# [Errno 2] No such file or directory: 'kaggle/working'
# /kaggle/working

# %%
# !git clone https://github.com/SimoneSgalla053/test-training-p3id.git
# !git checkout fix/training
# !git pull
# Out:
# Cloning into 'test-training-p3id'...
# remote: Enumerating objects: 205, done.
# remote: Counting objects: 100% (205/205), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 205 (delta 105), reused 165 (delta 69), pack-reused 0 (from 0)
# Receiving objects: 100% (205/205), 131.75 KiB | 3.87 MiB/s, done.
# Resolving deltas: 100% (105/105), done.
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# %cd test-training-p3id
# Out:
# /kaggle/working/test-training-p3id

# %%
import yaml
from pathlib import Path

repo = Path("/kaggle/working/test-training-p3id")
source_config = repo / "configs/road_2D.yaml"
kaggle_config = repo / "configs/kaggle_2D.yaml"

with source_config.open() as file:
    config = yaml.safe_load(file)

config["DATA"]["DATA_PATH"] = "/kaggle/input/datasets/simonesgalla/pid2graph-patched"
config["TRAIN"]["SAVE_PATH"] = "/kaggle/working/trained_weights"
config["DATA"]["BATCH_SIZE"] = 12
config["DATA"]["NUM_WORKERS"] = 0

with kaggle_config.open("w") as file:
    yaml.safe_dump(config, file, sort_keys=False)

# %%
# !pip install -q \
  einops \
  matplotlib \
  monai \
  PyYAML \
  scikit-image \
  scipy \
  tensorboardX \
  timm \
  loguru \
  sknw \
  Rtree \
  svgwrite \
  hopcroftkarp \
  tqdm \
  pytorch-ignite \
  tensorboard
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 4.1 MB/s eta 0:00:00
# ...

# %%
# !pip install -q mmcv==1.7.2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.8/607.8 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 19.0 MB/s eta 0:00:00
# ...

# %%
# %cd models/ops
# !pip install -v --no-build-isolation .
# Out:
# /kaggle/working/test-training-p3id/models/ops
# Using pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
# Processing /kaggle/working/test-training-p3id/models/ops
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-m49w4cx3/MultiScaleDeformableAttention.egg-info
#   writing /tmp/pip-pip-egg-info-m49w4cx3/MultiScaleDeformableAttention.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-m49w4cx3/MultiScaleDeformableAttention.egg-info/dependency_links.txt
#   writing top-level names to /tmp/pip-pip-egg-info-m49w4cx3/MultiScaleDeformableAttention.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-m49w4cx3/MultiScaleDeformableAttention.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-m49w4cx3/MultiScaleDeformableAttention.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-m49w4cx3/MultiScaleDeformableAttention.egg-info/SOURCES.txt'
# ...

# %%
# %cd ../..
# !python train.py --config configs/kaggle_2D.yaml --cuda_visible_device 0 1
# Out:
# /kaggle/working/test-training-p3id
#
# *** Config file
# configs/kaggle_2D.yaml
# Relationformer for the reduced patched P&ID line graph dataset
# /kaggle/working/test-training-p3id/metric_smd.py:509: SyntaxWarning: invalid escape sequence '\e'
#   "$M_{ij} = (-c_{ij} + u_i + v_j) / \epsilon$"
# /kaggle/working/test-training-p3id/models/ops/modules/ms_deform_attn.py:83: SyntaxWarning: invalid escape sequence '\s'
#   :param input_flatten               (N, \sum_{l=0}^{L-1} H_l \cdot W_l, C)
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...
